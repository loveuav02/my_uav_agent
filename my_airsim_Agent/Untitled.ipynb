# %%
from smolagents import CodeAgent, LiteLLMModel

model = LiteLLMModel(
    model_id="volcengine/deepseek-v4-flash-ga-260731", # This model is a bit weak for agentic behaviours though
    api_base="https://ark.cn-beijing.volces.com/api/v3", # replace with 127.0.0.1:11434 or remote open-ai compatible server if necessary
    api_key="", # replace with API key if necessary，写自己的key
)

# %%
from smolagents import tool

@tool
def hello(your_name: str) -> str:
    """
    这个工具返回三体人给你的第一句话

    Args:
        your_name: 你的名字
    """
    word = "Hello World, " + "Hello " + your_name  
    return word

# %%
from smolagents import CodeAgent
agent = CodeAgent(tools=[hello], model=model)
agent.run(
    "你是maris，你利用太阳反射波，和三体建立了第一次连接，三体人发送的第一句话是什么？"
)
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ 你是maris，你利用太阳反射波，和三体建立了第一次连接，三体人发送的第一句话是什么？                               │
# │                                                                                                                 │
# ╰─ LiteLLMModel - volcengine/deepseek-v4-flash-ga-260731 ─────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   first_message = hello(your_name="maris")
#   print(first_message)
#   final_answer(first_message)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# Hello World, Hello maris
# Final answer: Hello World, Hello maris
# [Step 1: Duration 4.52 seconds| Input tokens: 2,050 | Output tokens: 371]
# 'Hello World, Hello maris'

# %% [markdown]
# # 无人机自主搜索
